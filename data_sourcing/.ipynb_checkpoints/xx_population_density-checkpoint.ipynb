# %%
import ee
import xarray as xr
import pandas as pd
import numpy as np
import dask.array as da
import xee
from bbox import * 
from datetime import datetime

# Trigger the authentication flow
ee.Authenticate()

# Initialize the Earth Engine library
ee.Initialize(project='satellite-modeling')

# Define the rectangle that encompasses Louisiana and Texas
bbox = ee.Geometry.Rectangle([lon_min, lat_min, lon_max, lat_max])

start_date = '2023-07-31'
end_date = datetime.now().strftime('%Y-%m-%d')
# Out:
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_0JLhFqfSY1uiEaW?source=Init

# %%
no2_hours = pd.read_csv("../../data/tempo_data/no2_file_hours.csv")
no2_hours=list(no2_hours['time_hr_ct'])
time_list = np.array(no2_hours, dtype="datetime64[ns]")

# %%
##################################################
# Load GEOS-CF Data
##################################################

# List of climate variables to download from NLDAS
variables =['Q2M', 'T2M', 'U10M', 'V10M']

# Load NLDAS hourly data and filter by region and date
dataset = ee.ImageCollection("NASA/GEOS-CF/v1/rpl/tavg1hr") \
            .filterDate(start_date, end_date) \
            .filterBounds(bbox) \
            .select(variables)

ds = xr.open_dataset(dataset, engine='ee', crs='EPSG:4326', scale=0.01)
# Filter the dataset based on the latitude and longitude bounds
ds = ds.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))

# %%
ds['temp_celsius'] = ds['T2M'] - 273.15
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/ee/data.py:406, in _execute_cloud_call(call, num_retries)
#     405 try:
# --> 406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/satellite-modeling/image:computePixels? returned "Total request size (58982400 bytes) must be less than or equal to 50331648 bytes.". Details: "Total request size (58982400 bytes) must be less than or equal to 50331648 bytes.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds['temp_celsius'] = ds['T2M'] - 273.15
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/_typed_ops.py:412, in DataArrayOpsMixin.__sub__(self, other)
#     411 def __sub__(self, other: DaCompatible) -> Self:
# --> 412     return self._binary_op(other, operator.sub)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/dataarray.py:4781, in DataArray._binary_op(self, other, f, reflexive)
#    4777 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
#    4778 other_coords = getattr(other, "coords", None)
#    4780 variable = (
# -> 4781     f(self.variable, other_variable_or_arraylike)
#    4782     if not reflexive
#    4783     else f(other_variable_or_arraylike, self.variable)
#    4784 )
#    4785 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
#    4786 name = result_name([self, other])
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/_typed_ops.py:636, in VariableOpsMixin.__sub__(self, other)
#     635 def __sub__(self, other: VarCompatible) -> Self | T_DA:
# --> 636     return self._binary_op(other, operator.sub)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/variable.py:2330, in Variable._binary_op(self, other, f, reflexive)
#    2328     other_data, self_data, dims = _broadcast_compat_data(other, self)
#    2329 else:
# -> 2330     self_data, other_data, dims = _broadcast_compat_data(self, other)
#    2331 keep_attrs = _get_keep_attrs(default=False)
#    2332 attrs = self._attrs if keep_attrs else None
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/variable.py:2946, in _broadcast_compat_data(self, other)
#    2943     dims = new_self.dims
#    2944 else:
#    2945     # rely on numpy broadcasting rules
# -> 2946     self_data = self.data
#    2947     other_data = other
#    2948     dims = self.dims
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/variable.py:462, in Variable.data(self)
#     460     return self._data
#     461 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 462     return self._data.get_duck_array()
#     463 else:
#     464     return self.values
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/indexing.py:840, in MemoryCachedArray.get_duck_array(self)
#     839 def get_duck_array(self):
# --> 840     self._ensure_cached()
#     841     return self.array.get_duck_array()
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/indexing.py:837, in MemoryCachedArray._ensure_cached(self)
#     836 def _ensure_cached(self):
# --> 837     self.array = as_indexable(self.array.get_duck_array())
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/indexing.py:794, in CopyOnWriteArray.get_duck_array(self)
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/indexing.py:657, in LazilyIndexedArray.get_duck_array(self)
#     653     array = apply_indexer(self.array, self.key)
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xee/ext.py:809, in EarthEngineBackendArray.__getitem__(self, key)
#     808 def __getitem__(self, key: indexing.ExplicitIndexer) -> np.typing.ArrayLike:
# --> 809   return indexing.explicit_indexing_adapter(
#     810       key,
#     811       self.shape,
#     812       indexing.IndexingSupport.BASIC,
#     813       self._raw_indexing_method,
#     814   )
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     996 """Support explicit indexing by delegating to a raw indexing method.
#     997
#     998 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1015 Indexing result, in the form of a duck numpy-array.
#    1016 """
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#    1021     indexable = NumpyIndexingAdapter(result)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xee/ext.py:941, in EarthEngineBackendArray._raw_indexing_method(self, key)
#     933 tiles = [
#     934     [[None for _ in range(shape[2])] for _ in range(shape[1])]
#     935     for _ in range(shape[0])
#     936 ]
#     938 with concurrent.futures.ThreadPoolExecutor(
#     939     **self.store.executor_kwargs
#     940 ) as pool:
# --> 941   for (i, j, k), arr in pool.map(
#     942       self._make_tile, self._tile_indexes(key[0], bbox)
#     943   ):
#     944     tiles[i][j][k] = arr
#     946 out = np.block(tiles)
#
# File /opt/conda/envs/gee_env/lib/python3.13/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /opt/conda/envs/gee_env/lib/python3.13/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /opt/conda/envs/gee_env/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/conda/envs/gee_env/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/conda/envs/gee_env/lib/python3.13/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xee/ext.py:959, in EarthEngineBackendArray._make_tile(self, tile_index)
#     957 tile_idx, (istart, iend, *bbox) = tile_index
#     958 target_image = self._slice_collection(slice(istart, iend))
# --> 959 return tile_idx, self.store.image_to_array(
#     960     target_image, grid=self.store.project(tuple(bbox)), dtype=self.dtype
#     961 )
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xee/ext.py:502, in EarthEngineStore.image_to_array(self, image, pixels_getter, dtype, **kwargs)
#     496 image = image.unmask(self.mask_value, False)
#     497 params = {
#     498     'expression': image,
#     499     'fileFormat': 'NUMPY_NDARRAY',
#     500     **kwargs,
#     501 }
# --> 502 raw = common.robust_getitem(
#     503     pixels_getter,
#     504     params,
#     505     catch=ee.ee_exception.EEException,
#     506     **self.getitem_kwargs,
#     507 )
#     509 # Extract out the shape information from EE response.
#     510 y_size, x_size = raw.shape
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xarray/backends/common.py:175, in robust_getitem(array, key, catch, max_retries, initial_delay)
#     173 for n in range(max_retries + 1):
#     174     try:
# --> 175         return array[key]
#     176     except catch:
#     177         if n == max_retries:
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/xee/ext.py:99, in _GetComputedPixels.__getitem__(self, params)
#      98 def __getitem__(self, params) -> np.ndarray:
# ---> 99   return ee.data.computePixels(params)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/ee/data.py:952, in computePixels(params)
#     948 params['fileFormat'] = _cloud_api_utils.convert_to_image_file_format(
#     949     converter.expected_data_format()
#     950 )
#     951 _maybe_populate_workload_tag(params)
# --> 952 data = _execute_cloud_call(
#     953     _get_cloud_projects_raw()
#     954     .image()
#     955     .computePixels(project=_get_projects_path(), body=params)
#     956 )
#     957 if converter:
#     958   return converter.do_conversion(data)
#
# File /opt/conda/envs/gee_env/lib/python3.13/site-packages/ee/data.py:408, in _execute_cloud_call(call, num_retries)
#     406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
# --> 408   raise _translate_cloud_exception(e)
#
# EEException: Total request size (58982400 bytes) must be less than or equal to 50331648 bytes.

# %%
##################################################
# Change Timestamps
##################################################
# Recreate UTC Time Stamps
ds_time_list = ds["time"].values.tolist()
timestamps_utc = pd.to_datetime(ds_time_list)
timestamps_utc = timestamps_utc.tz_localize('UTC')

# Convert to Central Time (handles daylight saving time automatically)
timestamps_central = timestamps_utc.tz_convert('America/Chicago')
timestamps_central = timestamps_central.tz_localize(None)
timestamps_central=np.array(timestamps_central, dtype="datetime64[ns]")
# Replace the time dimension
ds = ds.assign_coords(time=timestamps_central)

# Remove duplicate hour from time change
ds = ds.isel(time=ds.get_index("time").duplicated() == False)

# %%
# Find dates included in both sat and weather data
seta = set(timestamps_central)
setb = set(time_list)
union_set = seta & setb
full_time_list = list(union_set)
filtered_ds = ds.sel(time=full_time_list)

# %%
filtered_ds
# Out:
# <xarray.Dataset> Size: 76GB
# Dimensions:     (time: 5351, lon: 1060, lat: 480)
# Coordinates:
#   * lon         (lon) float64 8kB -98.9 -98.89 -98.88 ... -88.32 -88.31 -88.3
#   * lat         (lat) float64 4kB 28.61 28.62 28.63 28.64 ... 33.37 33.38 33.39
#   * time        (time) datetime64[ns] 43kB 2023-08-02T12:00:00 ... 2024-05-29...
# Data variables:
#     CO          (time, lon, lat) float32 11GB ...
#     NO2         (time, lon, lat) float32 11GB ...
#     O3          (time, lon, lat) float32 11GB ...
#     TOTCOL_O3   (time, lon, lat) float32 11GB ...
#     TOTCOL_NO2  (time, lon, lat) float32 11GB ...
#     NO          (time, lon, lat) float32 11GB ...
#     SO2         (time, lon, lat) float32 11GB ...
# Attributes:
#     crs:      EPSG:4326

# %%
from dask.diagnostics import ProgressBar

# Convert to dask dataframe for chunking, stops to_netcdf from killing kernel
ds_dask = filtered_ds.chunk({'time': 20}) 

# Use ProgressBar to show the progress
with ProgressBar():
    # Save the Dask-backed xarray to NetCDF in Google Cloud Storage
    ds_dask.to_netcdf('../../data/other_hourly/geos_cf.nc', engine='h5netcdf')
## Other option
# ds_dask.to_zarr('../data/weather_data/weather_data.zarr', mode='w')

# %%
# import matplotlib.pyplot as plt
# # Define your latitude and longitude bounds
# lat_min, lat_max = 28.6, 33.4  # Example latitude range
# lon_min, lon_max = -98.9, -88.3  # Example longitude range

# # Select one hour of temperature data (e.g., the first timestamp)
# hour_index = 1  # Change this to select a different hour if desired
# temperature_data = ds['T'].isel(time=hour_index)

# # Plot the data with switched axes
# plt.figure(figsize=(10, 6))

# # Plot with latitude on x-axis and longitude on y-axis
# temperature_data.T.plot(
#     cmap="coolwarm",  # Colormap for temperature visualization
#     cbar_kwargs={'label': 'Temperature (K)'}  # Add color bar label
# )

# # Update axis labels
# plt.xlabel("Latitude")
# plt.ylabel("Longitude")

# plt.show()
